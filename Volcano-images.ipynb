# %% [markdown]
# # Trying to scrape Iceland Volcano images (and failing)

# %%
import os
import io
import sys
import urllib
import lxml
from lxml import html
import requests
import datetime
from platform import python_version
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from urllib.request import urlopen
from PIL import Image
from urllib.parse import urljoin

# %%
image_dir = 'images'
if not os.path.exists(image_dir):
    os.mkdir(image_dir)

# %%
url = "https://www.vedur.is/photos/camMeradalahnukurSV/"
# img file format : "210624_0440.jpg"
year, month, day = (2021, 6, 25)
hrs, mins = (4, 0)
dt = datetime.datetime(year, month, day, hrs, mins, 0)
dt_str = dt.strftime("%y%m%d_%H%M")
dt_str
# Out:
# '210625_0400'

# %%
urljoin(url, dt_str)
# https://www.vedur.is/photos/camMeradalahnukurSV/210624_0520.jpg
# Out:
# 'https://www.vedur.is/photos/camMeradalahnukurSV/210625_0400'

# %%
img = Image.open(io.BytesIO(urlopen(url).read(urljoin(url, dt_str))))
img.size
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-5-c0e9bc70967d> in <module>
# ----> 1 img = Image.open(io.BytesIO(urlopen(url).read(urljoin(url, dt_str))))
#       2 img.size
#
# /anaconda3/envs/web/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /anaconda3/envs/web/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ...

# %%
img

# %%
file_path = f"images/image-{dt_str}.jpg"
img.save(file_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-3471c883df28> in <module>
#       1 # It worked once then I think I was blocked
#       2 file_path = f"images/image-{dt_str}.jpg"
# ----> 3 img.save(file_path)
#
# NameError: name 'img' is not defined

# %%
# It worked once then I think I was blocked!
Image.open("images/image1.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=540x304 at 0x120E2D610>
